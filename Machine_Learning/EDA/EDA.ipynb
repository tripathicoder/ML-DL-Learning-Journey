# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## asking basic

# %% [raw]
# df=pd.read_csv('aug_train.csv')
# df.shape
# df.head()
# df.sample(5)

# %%
df.info
df.isnull().sum()
df.describe()
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## EDA univariant

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
df.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df=pd.read_csv('train.csv')
df.sample(5)
sns.countplot(x='Survived', data=df)
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=10)
sns.distplot(df['Age'])
sns.boxplot(df['Age'])
# Out:
# C:\Users\Shudhanshu\AppData\Local\Temp\ipykernel_7448\3916353473.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df['Age'].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
import pandas as pd
# !pip install ydata-profiling
# Out:
# Requirement already satisfied: ydata-profiling in c:\users\shudhanshu\anaconda3\lib\site-packages (4.18.4)
# Requirement already satisfied: scipy<1.17,>=1.8 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (1.16.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (2.12.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: numpy<2.4,>=1.22 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (2.3.5)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\users\shudhanshu\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\users\shudhanshu\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shudhanshu\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\shudhanshu\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shudhanshu\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shudhanshu\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.11.12)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\shudhanshu\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\shudhanshu\anaconda3\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\shudhanshu\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Requirement already satisfied: puremagic in c:\users\shudhanshu\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)

# %%
import pandas as pd
import numpy as np
from ydata_profiling import ProfileReport

df = pd.read_csv('train.csv')

prof = ProfileReport(df)

prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from ydata_profiling import ProfileReport
#       5 df = pd.read_csv('train.csv')
#       7 prof = ProfileReport(df)
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:32
#      30 from ydata_profiling.model import BaseDescription
#      31 from ydata_profiling.model.alerts import AlertType
# ---> 32 from ydata_profiling.model.describe import describe as describe_df
#      33 from ydata_profiling.model.sample import Sample
#      34 from ydata_profiling.model.summarizer import (
#      35     BaseSummarizer,
#      36     ProfilingSummarizer,
#      37     format_summary,
#      38     redact_summary,
#      39 )
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\model\describe.py:16
#      11 from ydata_profiling.model.alerts import get_alerts
#      12 from ydata_profiling.model.correlations import (
#      13     calculate_correlation,
#      14     get_active_correlations,
#      15 )
# ---> 16 from ydata_profiling.model.dataframe import preprocess
#      17 from ydata_profiling.model.description import TimeIndexAnalysis
#      18 from ydata_profiling.model.duplicates import get_duplicates
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\model\dataframe.py:7
#       4 import pandas as pd
#       6 from ydata_profiling.config import Settings
# ----> 7 from ydata_profiling.model.pandas.dataframe_pandas import pandas_preprocess
#       9 spec = importlib.util.find_spec("pyspark")
#      10 if spec is None:
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\__init__.py:27
#      25 # Dynamically import and expose functions from modules
#      26 for module_name in PANDAS_MODULES:
# ---> 27     module = importlib.import_module(f"ydata_profiling.model.pandas.{module_name}")
#      28     globals().update(
#      29         {
#      30             name: getattr(module, name)
#    (...)     33         }
#      34     )
#      36 # Explicitly list exposed names for clarity
#
# File ~\anaconda3\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\correlations_pandas.py:8
#       6 import numpy as np
#       7 import pandas as pd
# ----> 8 from scipy import stats
#      10 from ydata_profiling.config import Settings
#      11 from ydata_profiling.model.pandas.discretize_pandas import (
#      12     DiscretizationType,
#      13     Discretizer,
#      14 )
#
# File ~\anaconda3\Lib\site-packages\scipy\__init__.py:131, in __getattr__(name)
#     129 def __getattr__(name):
#     130     if name in submodules:
# --> 131         return _importlib.import_module(f'scipy.{name}')
#     132     else:
#     133         try:
#
# File ~\anaconda3\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\anaconda3\Lib\site-packages\scipy\stats\__init__.py:626
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    621
#     622 """  # noqa: E501
#     624 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     625                                DegenerateDataWarning, FitError)
# --> 626 from ._stats_py import *
#     627 from ._variation import variation
#     628 from .distributions import *
#
# File ~\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:39
#      36 import numpy as np
#      37 from numpy import array, asarray, ma
# ---> 39 from scipy import sparse
#      40 from scipy.spatial import distance_matrix
#      42 from scipy.optimize import milp, LinearConstraint
#
# File ~\anaconda3\Lib\site-packages\scipy\__init__.py:131, in __getattr__(name)
#     129 def __getattr__(name):
#     130     if name in submodules:
# --> 131         return _importlib.import_module(f'scipy.{name}')
#     132     else:
#     133         try:
#
# File ~\anaconda3\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\__init__.py:304
#     301 import warnings as _warnings
#     302 import importlib as _importlib
# --> 304 from ._base import *
#     305 from ._csr import *
#     306 from ._csc import *
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_base.py:8
#       5 import numpy as np
#       6 import operator
# ----> 8 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       9                        get_sum_dtype, isdense, isscalarlike, _todata,
#      10                        matrix, validateaxis, getdtype, is_pydata_spmatrix)
#      11 from scipy._lib._sparse import SparseABC, issparse
#      13 from ._matrix import spmatrix
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_sputils.py:10
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      13 __all__ = ['upcast', 'getdtype', 'getdata', 'isscalarlike', 'isintlike',
#      14            'isshape', 'issequence', 'isdense', 'ismatrix', 'get_sum_dtype',
#      15            'broadcast_shapes']
#      17 supported_dtypes = [np.bool_, np.byte, np.ubyte, np.short, np.ushort, np.intc,
#      18                     np.uintc, np_long, np_ulong, np.longlong, np.ulonglong,
#      19                     np.float32, np.float64, np.longdouble,
#      20                     np.complex64, np.complex128, np.clongdouble]
#
# File ~\anaconda3\Lib\site-packages\scipy\_lib\_util.py:14
#      11 from typing import Literal, TypeAlias, TypeVar
#      13 import numpy as np
# ---> 14 from scipy._lib._array_api import (Array, array_namespace, is_lazy_array,
#      15                                    is_numpy, is_marray, xp_result_device,
#      16                                    xp_size, xp_result_type)
#      17 from scipy._lib._docscrape import FunctionDoc, Parameter
#      18 from scipy._lib._sparse import issparse
#
# File ~\anaconda3\Lib\site-packages\scipy\_lib\_array_api.py:22
#      19 from typing import Any, Literal, TypeAlias
#      21 import numpy as np
# ---> 22 import numpy.typing as npt
#      24 from scipy._lib import array_api_compat
#      25 from scipy._lib.array_api_compat import (
#      26     is_array_api_obj,
#      27     is_lazy_array,
#    (...)     36     is_array_api_strict_namespace as is_array_api_strict
#      37 )
#
# ModuleNotFoundError: No module named 'numpy.typing'

# %%
# !pip install --upgrade numpy
# Out:
# Requirement already satisfied: numpy in c:\users\shudhanshu\anaconda3\lib\site-packages (2.3.5)
# Collecting numpy
#   Downloading numpy-2.4.6-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.6-cp313-cp313-win_amd64.whl (12.3 MB)
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.3 MB 2.9 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.3/12.3 MB 2.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.8/12.3 MB 2.7 MB/s eta 0:00:04
#    -------- ------------------------------- 2.6/12.3 MB 2.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 3.1/12.3 MB 2.9 MB/s eta 0:00:04
#    ------------ --------------------------- 3.9/12.3 MB 3.0 MB/s eta 0:00:03
#    --------------- ------------------------ 4.7/12.3 MB 3.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.5/12.3 MB 3.1 MB/s eta 0:00:03
#    -------------------- ------------------- 6.3/12.3 MB 3.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.1/12.3 MB 3.2 MB/s eta 0:00:02
#    ------------------------- -------------- 7.9/12.3 MB 3.3 MB/s eta 0:00:02
#    ---------------------------- ----------- 8.9/12.3 MB 3.4 MB/s eta 0:00:02
#    ------------------------------- -------- 9.7/12.3 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.5/12.3 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------- -- 11.5/12.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  12.1/12.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.3/12.3 MB 3.5 MB/s  0:00:03
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.5
#     Uninstalling numpy-2.3.5:
#       Successfully uninstalled numpy-2.3.5
# Successfully installed numpy-2.3.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.62.1 requires numpy<2.4,>=1.22, but you have numpy 2.4.6 which is incompatible.
# ydata-profiling 4.18.4 requires numpy<2.4,>=1.22, but you have numpy 2.4.6 which is incompatible.

# %%
# !pip install --upgrade scipy ydata-profiling
# Out:
# Requirement already satisfied: scipy in c:\users\shudhanshu\anaconda3\lib\site-packages (1.16.3)
# Collecting scipy
#   Downloading scipy-1.17.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: ydata-profiling in c:\users\shudhanshu\anaconda3\lib\site-packages (4.18.4)
# Requirement already satisfied: numpy<2.7,>=1.26.4 in c:\users\shudhanshu\anaconda3\lib\site-packages (from scipy) (2.3.5)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (2.3.3)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (3.10.0)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (2.12.4)
# Requirement already satisfied: PyYAML<6.1,>=6.0.3 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (6.0.3)
# Requirement already satisfied: jinja2<3.2,>=3.1.6 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: visions<0.8.2,>=0.7.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (0.8.1)
# Requirement already satisfied: minify-html>=0.15.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (0.18.1)
# Requirement already satisfied: filetype>=1.0.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (1.2.0)
# Requirement already satisfied: phik<0.13,>=0.12.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.32.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (2.32.5)
# Requirement already satisfied: tqdm<5,>=4.66.3 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (4.67.1)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (0.14.5)
# Requirement already satisfied: typeguard<5,>=4 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (4.5.2)
# Requirement already satisfied: imagehash==4.3.2 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (4.3.2)
# Requirement already satisfied: wordcloud>=1.9.4 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (1.9.6)
# Requirement already satisfied: dacite<2,>=1.9 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (1.9.2)
# Requirement already satisfied: numba<0.63,>=0.60 in c:\users\shudhanshu\anaconda3\lib\site-packages (from ydata-profiling) (0.62.1)
# Requirement already satisfied: PyWavelets in c:\users\shudhanshu\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (1.9.0)
# Requirement already satisfied: pillow in c:\users\shudhanshu\anaconda3\lib\site-packages (from imagehash==4.3.2->ydata-profiling) (12.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from jinja2<3.2,>=3.1.6->ydata-profiling) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shudhanshu\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from numba<0.63,>=0.60->ydata-profiling) (0.45.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\shudhanshu\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from phik<0.13,>=0.12.5->ydata-profiling) (1.5.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\shudhanshu\anaconda3\lib\site-packages (from pydantic<3,>=2->ydata-profiling) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shudhanshu\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shudhanshu\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shudhanshu\anaconda3\lib\site-packages (from requests<3,>=2.32.0->ydata-profiling) (2025.11.12)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\shudhanshu\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\shudhanshu\anaconda3\lib\site-packages (from tqdm<5,>=4.66.3->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\shudhanshu\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (25.4.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\shudhanshu\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (3.5)
# Requirement already satisfied: puremagic in c:\users\shudhanshu\anaconda3\lib\site-packages (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\shudhanshu\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling) (1.17.0)

# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = pd.read_csv('train.csv')

profile = ProfileReport(df)
profile.to_file("output.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport
#       4 df = pd.read_csv('train.csv')
#       6 profile = ProfileReport(df)
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\__init__.py:11
#       8 import importlib.util  # isort:skip # noqa
#       9 from warnings import warn
# ---> 11 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      12 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      13 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ---> 12 from ydata_profiling.profile_report import ProfileReport
#      15 def _should_wrap(v1: Any, v2: Any) -> bool:
#      16     if isinstance(v1, (list, dict)):
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\profile_report.py:32
#      30 from ydata_profiling.model import BaseDescription
#      31 from ydata_profiling.model.alerts import AlertType
# ---> 32 from ydata_profiling.model.describe import describe as describe_df
#      33 from ydata_profiling.model.sample import Sample
#      34 from ydata_profiling.model.summarizer import (
#      35     BaseSummarizer,
#      36     ProfilingSummarizer,
#      37     format_summary,
#      38     redact_summary,
#      39 )
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\model\describe.py:16
#      11 from ydata_profiling.model.alerts import get_alerts
#      12 from ydata_profiling.model.correlations import (
#      13     calculate_correlation,
#      14     get_active_correlations,
#      15 )
# ---> 16 from ydata_profiling.model.dataframe import preprocess
#      17 from ydata_profiling.model.description import TimeIndexAnalysis
#      18 from ydata_profiling.model.duplicates import get_duplicates
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\model\dataframe.py:7
#       4 import pandas as pd
#       6 from ydata_profiling.config import Settings
# ----> 7 from ydata_profiling.model.pandas.dataframe_pandas import pandas_preprocess
#       9 spec = importlib.util.find_spec("pyspark")
#      10 if spec is None:
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\__init__.py:27
#      25 # Dynamically import and expose functions from modules
#      26 for module_name in PANDAS_MODULES:
# ---> 27     module = importlib.import_module(f"ydata_profiling.model.pandas.{module_name}")
#      28     globals().update(
#      29         {
#      30             name: getattr(module, name)
#    (...)     33         }
#      34     )
#      36 # Explicitly list exposed names for clarity
#
# File ~\anaconda3\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\anaconda3\Lib\site-packages\ydata_profiling\model\pandas\correlations_pandas.py:8
#       6 import numpy as np
#       7 import pandas as pd
# ----> 8 from scipy import stats
#      10 from ydata_profiling.config import Settings
#      11 from ydata_profiling.model.pandas.discretize_pandas import (
#      12     DiscretizationType,
#      13     Discretizer,
#      14 )
#
# File ~\anaconda3\Lib\site-packages\scipy\__init__.py:131, in __getattr__(name)
#     129 def __getattr__(name):
#     130     if name in submodules:
# --> 131         return _importlib.import_module(f'scipy.{name}')
#     132     else:
#     133         try:
#
# File ~\anaconda3\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\anaconda3\Lib\site-packages\scipy\stats\__init__.py:626
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)    621
#     622 """  # noqa: E501
#     624 from ._warnings_errors import (ConstantInputWarning, NearConstantInputWarning,
#     625                                DegenerateDataWarning, FitError)
# --> 626 from ._stats_py import *
#     627 from ._variation import variation
#     628 from .distributions import *
#
# File ~\anaconda3\Lib\site-packages\scipy\stats\_stats_py.py:39
#      36 import numpy as np
#      37 from numpy import array, asarray, ma
# ---> 39 from scipy import sparse
#      40 from scipy.spatial import distance_matrix
#      42 from scipy.optimize import milp, LinearConstraint
#
# File ~\anaconda3\Lib\site-packages\scipy\__init__.py:131, in __getattr__(name)
#     129 def __getattr__(name):
#     130     if name in submodules:
# --> 131         return _importlib.import_module(f'scipy.{name}')
#     132     else:
#     133         try:
#
# File ~\anaconda3\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\__init__.py:304
#     301 import warnings as _warnings
#     302 import importlib as _importlib
# --> 304 from ._base import *
#     305 from ._csr import *
#     306 from ._csc import *
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_base.py:8
#       5 import numpy as np
#       6 import operator
# ----> 8 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       9                        get_sum_dtype, isdense, isscalarlike, _todata,
#      10                        matrix, validateaxis, getdtype, is_pydata_spmatrix)
#      11 from scipy._lib._sparse import SparseABC, issparse
#      13 from ._matrix import spmatrix
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_sputils.py:10
#       8 from math import prod
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      13 __all__ = ['upcast', 'getdtype', 'getdata', 'isscalarlike', 'isintlike',
#      14            'isshape', 'issequence', 'isdense', 'ismatrix', 'get_sum_dtype',
#      15            'broadcast_shapes']
#      17 supported_dtypes = [np.bool_, np.byte, np.ubyte, np.short, np.ushort, np.intc,
#      18                     np.uintc, np_long, np_ulong, np.longlong, np.ulonglong,
#      19                     np.float32, np.float64, np.longdouble,
#      20                     np.complex64, np.complex128, np.clongdouble]
#
# File ~\anaconda3\Lib\site-packages\scipy\_lib\_util.py:14
#      11 from typing import Literal, TypeAlias, TypeVar
#      13 import numpy as np
# ---> 14 from scipy._lib._array_api import (Array, array_namespace, is_lazy_array,
#      15                                    is_numpy, is_marray, xp_result_device,
#      16                                    xp_size, xp_result_type)
#      17 from scipy._lib._docscrape import FunctionDoc, Parameter
#      18 from scipy._lib._sparse import issparse
#
# File ~\anaconda3\Lib\site-packages\scipy\_lib\_array_api.py:22
#      19 from typing import Any, Literal, TypeAlias
#      21 import numpy as np
# ---> 22 import numpy.typing as npt
#      24 from scipy._lib import array_api_compat
#      25 from scipy._lib.array_api_compat import (
#      26     is_array_api_obj,
#      27     is_lazy_array,
#    (...)     36     is_array_api_strict_namespace as is_array_api_strict
#      37 )
#
# ModuleNotFoundError: No module named 'numpy.typing'
